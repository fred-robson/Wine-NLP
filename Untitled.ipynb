# %% [markdown]
# # Defining Dependencies
#
# We will be using tensorflow for building our LSTM

# %%
import tensorflow as tf
import data_utils as du
import pandas as pd

# %% [markdown]
# # Analyzing Data
#
# We will need to clean and format our data for training. By getting some statistics and visualization for our data we will do a better job of accounting for missing data and augmenting existing features for training.

# %%
wine_utils = du.data_utils()
wine_data = wine_utils.load_data()

# %%
train_df = wine_data[0]
train_df
# Out:
#         Unnamed: 0    country  \
# 114630      114630     France
# 39275        39275         US
# 34144        34144         US
# 14243        14243         US
# 86564        86564         US
# 9390          9390  Argentina
# 120860      120860  Australia
# 2825          2825         US
# 125480      125480         US
# 100278      100278         US
# 99297        99297      Italy
# 84112        84112         US
# 64606        64606     France
# 69331        69331         US
# 79244        79244      Italy
# 115438      115438      Chile
# 60781        60781         US
# 39769        39769     France
# 60694        60694         US
# 37727        37727         US
# 98067        98067  Argentina
# 58604        58604         US
# 96174        96174         US
# 108174      108174     France
# 23085        23085     France
# 126376      126376    Germany
# 103411      103411      Italy
# 13576        13576      Chile
# 100458      100458      Spain
# 94189        94189     France
# ...            ...        ...
# 47563        47563         US
# 101363      101363         US
# 123601      123601         US
# 12473        12473     France
# 125166      125166         US
# 106695      106695         US
# 1825          1825         US
# 99952        99952         US
# 58458        58458     France
# 102537      102537         US
# 93787        93787      Chile
# 85663        85663         US
# 62000        62000         US
# 100982      100982      Italy
# 91499        91499         US
# 120158      120158      Chile
# 79165        79165     France
# 104248      104248     France
# 31628        31628         US
# 35906        35906         US
# 100769      100769      Italy
# 37246        37246         US
# 103681      103681   Portugal
# 21628        21628         US
# 15048        15048         US
# 120994      120994     France
# 100738      100738         US
# 115322      115322         US
# 123952      123952     France
# 48754        48754      Italy
#
#                                               description  \
# 114630  [This, mildly, aromatic, blend, of, Grenache, ...
# 39275   [Bright, and, alive, in, crisp, pear, and, fre...
# 34144   [This, pure, Malbec, carries, spicy, ,, slight...
# 14243   [A, toasty, streak, of, espresso, -, flavored,...
# 86564   [The, grapes, come, from, the, Applegate, vall...
# 9390    [This, ultraripe, Malbec, -, led, blend, sugge...
# 120860  [Penfolds', Bin, 51, is, a, perennial, winner,...
# 2825    [A, blend, of, six, different, varieties, with...
# 125480  [A, delightful, southern, Rhône, -, style, win...
# 100278  [The, nose, on, this, wine, by, Burgundy, -, r...
# 99297   [What, sets, this, Taurasi, apart, is, a, dist...
# 84112   [Tasting, off, -, dry, ,, this, has, flavors, ...
# 64606   [This, is, a, powerful, statement, of, ripe, C...
# 69331   [This, lovingly, made, wine, is, packed, with,...
# 79244   [This, opens, with, aromas, of, woodshop, ,, s...
# 115438  [A, jumbled, mix, of, aromas, includes, notes,...
# 60781   [A, little, heavy, and, soft, ,, with, jelled,...
# 39769   [You, can, tell, the, age, from, the, color, a...
# 60694   [Pressed, berries, ,, plum, flesh, ,, toasted,...
# 37727   [This, winery, is, making, one, of, the, best,...
# 98067   [This, almost, translucent, brick, -, colored,...
# 58604   [A, beautiful, Pinot, Noir, ,, showing, off, t...
# 96174   [Drink, this, Merlot, with, burgers, at, a, pa...
# 108174  [Soft, and, rounded, ,, this, has, an, attract...
# 23085   [Just, beginning, to, mature, ,, this, generou...
# 126376  [A, pale, ,, lemon, color, Riesling, ., The, c...
# 103411  [This, Riserva, Brunello, offers, excellent, d...
# 13576   [A, flat, bouquet, smells, mostly, of, root, b...
# 100458  [A, new, take, on, Harveys, Bristol, Cream, .,...
# 94189   [Pascal, Bouchard's, entry, -, level, Chablis,...
# ...                                                   ...
# 47563   [Fresh, apple, blossoms, ,, lemongrass, ,, Mey...
# 101363  [Light, in, color, ,, this, wine, offers, high...
# 123601  [The, raspberry, and, cherry, flavors, are, a,...
# 12473   [Produced, to, be, consumed, young, ,, this, i...
# 125166  [This, is, a, wonderfully, dry, ,, crisp, and,...
# 106695  [The, Huber, Vineyard, is, one, of, the, few, ...
# 1825    [Forest, berries, ,, perfumed, violets, and, p...
# 99952   [Notes, of, hazelnut, and, freshly, baked, bri...
# 58458   [With, its, crisp, texture, ,, this, wine, is,...
# 102537  [The, oak, influence, currently, sits, high, o...
# 93787   [Attractive, and, correct, berry, ,, plum, and...
# 85663   [Some, Sonoma, Coast, Pinots, are, dark, ,, he...
# 62000   [An, aroma, of, fresh, -, cut, pear, introduce...
# 100982  [Fragrances, suggest, white, spring, flower, a...
# 91499   [The, Peach, Tree, cuvée, actually, carries, a...
# 120158  [Shows, some, roughness, and, burnt, leaves, o...
# 79165   [This, is, an, intensely, fruity, wine, ,, fla...
# 104248  [This, is, from, Alsace's, only, Grand, Cru, v...
# 31628   [From, two, vineyard, sources, in, Lodi, ,, Uv...
# 35906   [Spicy, ,, lemony, acidity, balances, out, a, ...
# 100769  [A, tiny, element, (, just, 3, %, ), of, Chard...
# 37246   [This, exotic, and, memorable, white, wine, br...
# 103681  [Syrah, grown, in, sandy, soil, just, above, t...
# 21628   [The, Rutherford, vineyard, has, been, the, so...
# 15048   [A, delicious, Pinot, Noir, ,, made, in, the, ...
# 120994  [Lifted, peach, and, chamomile, just, hint, at...
# 100738  [A, good, ,, dry, and, elegant, bubbly, ., Sho...
# 115322  [Stunningly, good, ,, this, offers, off, -, dr...
# 123952  [A, lovely, lemony, lift, jumps, from, the, gl...
# 48754   [Aromas, of, baked, plum, ,, mature, berry, ,,...
#
#                         designation  points  price           province  \
# 114630             Les Galets Dorés      86   14.0       Rhône Valley
# 39275               Limited Release      91   35.0         California
# 34144        Pepper Bridge Vineyard      90   32.0         Washington
# 14243        Corral Creek Vineyards      88   48.0             Oregon
# 86564                           NaN      85   10.0             Oregon
# 9390                           Alto      93   85.0   Mendoza Province
# 120860                       Bin 51      91   40.0    South Australia
# 2825                            NaN      86   12.0         Washington
# 125480                Le P'tit Pape      90   22.0         California
# 100278                  La Pristina      93   30.0         California
# 99297           Tenuta di Altavilla      92    NaN     Southern Italy
# 84112             Vintner's Reserve      85   13.0         California
# 64606                           NaN      92  100.0           Bordeaux
# 69331           Ghielmetti Vineyard      90   60.0         California
# 79244                       Riserva      87   30.0      Central Italy
# 115438                Monster Block      87   30.0  Casablanca Valley
# 60781             Ramona Pinot Noir      83   20.0         California
# 39769                           NaN      84   30.0   Southwest France
# 60694                      Quixotic      89    NaN         California
# 37727                 Barrel Select      93   65.0         California
# 98067                   Eggo Filoso      89   30.0   Mendoza Province
# 101363                                   Washington   Washington Other
# 123601                        Santa Lucia Highlands      Central Coast
# 12473                                        Cahors                NaN
# 125166                                   California   California Other
# 106695                              Sta. Rita Hills      Central Coast
# 1825                                  Central Coast      Central Coast
# 99952                                  Finger Lakes       Finger Lakes
# 58458                                Pouilly-Fuissé                NaN
# 102537                                     Virginia                NaN
# 93787                                           NaN                NaN
# 85663                                  Sonoma Coast             Sonoma
# 62000                                 Yakima Valley    Columbia Valley
# 100982                               Soave Classico                NaN
# 91499                                  Dundee Hills  Willamette Valley
# 120158                                          NaN                NaN
# 79165                             Côtes de Gascogne                NaN
# 104248                                       Alsace                NaN
# 31628                                          Lodi     Central Valley
# 35906                                  Sonoma Coast             Sonoma
# 100769  Conegliano Valdobbiadene Prosecco Superiore                NaN
# 37246                              Sierra Foothills   Sierra Foothills
# 103681                                          NaN                NaN
# 21628                                   Napa Valley               Napa
# 15048                          Russian River Valley             Sonoma
# 120994                                       Alsace                NaN
# 100738                                Sonoma County             Sonoma
# 115322                            Willamette Valley                NaN
# 123952                                       Alsace                NaN
# 48754                          Carignano del Sulcis                NaN
#
#                taster_name taster_twitter_handle  \
# 114630      Joe Czerwinski                @JoeCz
# 39275       Virginie Boone               @vboone
# 34144         Paul Gregutt           @paulgwine
# 14243         Paul Gregutt           @paulgwine
# 86564         Paul Gregutt           @paulgwine
# 9390     Michael Schachner           @wineschach
# 120860      Joe Czerwinski                @JoeCz
# 2825      Sean P. Sullivan         @wawinereport
# 125480                 NaN                   NaN
# 100278       Matt Kettmann         @mattkettmann
# 99297                  NaN                   NaN
# 84112                  NaN                   NaN
# 64606           Roger Voss            @vossroger
# 69331       Virginie Boone               @vboone
# 79244        Kerin O’Keefe          @kerinokeefe
# 115438   Michael Schachner           @wineschach
# 60781                  NaN                   NaN
# 39769           Roger Voss            @vossroger
# 60694        Matt Kettmann         @mattkettmann
# 37727        Matt Kettmann         @mattkettmann
# 98067    Michael Schachner           @wineschach
# 58604                  NaN                   NaN
# 96174                  NaN                   NaN
# 108174          Roger Voss            @vossroger
# 23085           Roger Voss            @vossroger
# 126376                 NaN                   NaN
# 103411                 NaN                   NaN
# 13576    Michael Schachner           @wineschach
# 100458   Michael Schachner           @wineschach
# 94189           Roger Voss            @vossroger
# ...                    ...                   ...
# 47563        Matt Kettmann         @mattkettmann
# 101363    Sean P. Sullivan         @wawinereport
# 123601                 NaN                   NaN
# 12473           Roger Voss            @vossroger
# 125166                 NaN                   NaN
# 106695       Matt Kettmann         @mattkettmann
# 1825         Matt Kettmann         @mattkettmann
# 99952   Anna Lee C. Iijima                   NaN
# 58458           Roger Voss            @vossroger
# 102537                 NaN                   NaN
# 93787                  NaN                   NaN
# 85663                  NaN                   NaN
# 62000         Paul Gregutt           @paulgwine
# 100982       Kerin O’Keefe          @kerinokeefe
# 91499         Paul Gregutt           @paulgwine
# 120158   Michael Schachner           @wineschach
# 79165           Roger Voss            @vossroger
# 104248    Anne Krebiehl MW           @AnneInVino
# 31628       Virginie Boone               @vboone
# 35906       Virginie Boone               @vboone
# 100769                 NaN                   NaN
# 37246           Jim Gordon      @gordone_cellars
# 79165            Sauvignon Blanc             Georges Vigouroux
# 104248                  Sylvaner                       Boeckel
# 31628                 Vermentino                       Uvaggio
# 35906                 Chardonnay                      Landmark
# 100769                     Glera                      Andreola
# 37246                  Torrontés                    Wise Villa
# 103681                     Syrah    Quinta da Lagoalva de Cima
# 21628         Cabernet Sauvignon          Monticello Vineyards
# 15048                 Pinot Noir                           HKG
# 120994                  Riesling                    Leon Beyer
# 100738           Sparkling Blend                 Gloria Ferrer
# 115322                  Riesling                        Brooks
# 123952                  Riesling                   Paul Blanck
# 48754                  Carignano                          Mesa
#
# [90979 rows x 14 columns]

# %%
for feature in train_df:
    total_entries =  len(train_df[feature])
    Num_Nan = train_df[feature].isnull().sum()
    print("Feature: {0} | Percent of NaN {1}".format(feature, float(Num_Nan)/float(total_entries)))
# Out:
# Feature: Unnamed: 0 | Percent of NaN 0.0
# Feature: country | Percent of NaN 0.0004946196374987635
# Feature: description | Percent of NaN 0.0
# Feature: designation | Percent of NaN 0.28924257246177687
# Feature: points | Percent of NaN 0.0
# Feature: price | Percent of NaN 0.06885105353982787
# Feature: province | Percent of NaN 0.0004946196374987635
# Feature: region_1 | Percent of NaN 0.162004418602095
# Feature: region_2 | Percent of NaN 0.610371624220974
# Feature: taster_name | Percent of NaN 0.20136515019949658
# Feature: taster_twitter_handle | Percent of NaN 0.23946185383440136
# Feature: title | Percent of NaN 0.0
# Feature: variety | Percent of NaN 1.0991547499972522e-05
# Feature: winery | Percent of NaN 0.0

# %% [markdown]
# # Define General Model for Running in TensorFlow

# %%
def do_train(args):
    # Set up some parameters.
    config = Config(args)
    helper, train, dev, train_raw, dev_raw = load_and_preprocess_data(args)
    embeddings = load_embeddings(args, helper)
    config.embed_size = embeddings.shape[1]
    helper.save(config.output_path)

    report = None #Report(Config.eval_output)

    with tf.Graph().as_default():
        logger.info("Building model...",)
        start = time.time()
        model = RNNModel(helper, config, embeddings)
        logger.info("took %.2f seconds", time.time() - start)

        init = tf.global_variables_initializer()
        saver = tf.train.Saver()

        with tf.Session() as session:
            session.run(init)
            model.fit(session, saver, train, dev)
            if report:
                report.log_output(model.output(session, dev_raw))
                report.save()
            else:
                # Save predictions in a text file.
                output = model.output(session, dev_raw)
                sentences, labels, predictions = zip(*output)
                predictions = [[LBLS[l] for l in preds] for preds in predictions]
                output = zip(sentences, labels, predictions)

                with open(model.config.conll_output, 'w') as f:
                    write_conll(f, output)
                with open(model.config.eval_output, 'w') as f:
                    for sentence, labels, predictions in output:
                        print_sentence(f, sentence, labels, predictions)

def do_evaluate(args):
    config = Config(args)
    helper = ModelHelper.load(args.model_path)
    input_data = read_conll(args.data)
    embeddings = load_embeddings(args, helper)
    config.embed_size = embeddings.shape[1]

    with tf.Graph().as_default():
        logger.info("Building model...",)
        start = time.time()
        model = RNNModel(helper, config, embeddings)

        logger.info("took %.2f seconds", time.time() - start)

        init = tf.global_variables_initializer()
        saver = tf.train.Saver()

        with tf.Session() as session:
            session.run(init)
            saver.restore(session, model.config.model_output)
            for sentence, labels, predictions in model.output(session, input_data):
                predictions = [LBLS[l] for l in predictions]
                print_sentence(args.output, sentence, labels, predictions)
